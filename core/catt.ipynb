# %% [markdown]
# # Begining
# Starting with monting our drive for the datasets

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %% [markdown]
# # Extracting
# extracting our model to the same directory as our run.py

# %%
# !tar -xvzf "/content/gdrive/My Drive/Colab Notebooks/dsets.tar.gz" -C "/content/gdrive/My Drive/Colab Notebooks/dsets"
# Out:
# dsets/
# dsets/normal_0_9954.jpeg
# dsets/hot_0_9678.jpeg
# dsets/hot_0_6576.jpeg
# dsets/hot_0_6496.jpeg
# dsets/hot_0_8756.jpeg
# dsets/hot_0_3430.jpeg
# dsets/normal_0_9089.jpeg
# dsets/normal_0_4562.jpeg
# dsets/hot_0_2042.jpeg
# dsets/hot_0_367.jpeg
# dsets/normal_0_6303.jpeg
# dsets/hot_0_8743.jpeg
# dsets/normal_0_6386.jpeg
# dsets/normal_0_9590.jpeg
# dsets/normal_0_9322.jpeg
# dsets/hot_195.png
# dsets/hot_0_2399.jpeg
# dsets/hot_0_7882.jpeg
# dsets/normal_0_4928.jpeg
# dsets/hot_0_9345.jpeg
# dsets/normal_0_2197.jpeg
# dsets/normal_0_992.jpeg
# dsets/hot_0_457.jpeg
# dsets/normal_0_8683.jpeg
# dsets/normal_0_9600.jpeg
# dsets/hot_0_7015.jpeg
# dsets/normal_0_3199.jpeg
# dsets/hot_0_7220.jpeg
# dsets/normal_0_613.jpeg
# dsets/normal_0_2313.jpeg
# dsets/hot_0_8317.jpeg
# dsets/normal_0_9565.jpeg
# dsets/hot_0_559.jpeg
# dsets/hot_0_6685.jpeg
# dsets/hot_0_9020.jpeg
# dsets/normal_0_9844.jpeg
# dsets/hot_0_8488.jpeg
# dsets/normal_0_5011.jpeg
# dsets/hot_0_9218.jpeg
# ...

# %% [markdown]
# # Training Model
# Loading the images dataset into memory and then training our model.

# %%
# !echo "[ ! ] Starting..."
# !cd "/content/gdrive/My Drive/Colab Notebooks" && python run.py -d "./dsets.csv" -e 10 # cd is a hack
