# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %%
# !ls "/content/gdrive/My Drive/Colab Notebooks"
# !tar -xzvf "/content/gdrive/My Drive/Colab Notebooks/datasets.tar.gz" -C "/content/gdrive/My Drive/Colab Notebooks/datasets"

# %%
# !ls "/content/gdrive/My Drive/Colab Notebooks"
# !mv "/content/gdrive/My Drive/Colab Notebooks/datasets (1)" "/content/gdrive/My Drive/Colab Notebooks/datasets"
# Out:
# 'datasets (1)'	 datasets.tar.gz   thermed.ipynb

# %%
# !rm -rf "/content/gdrive/My Drive/Colab Notebooks/datasets.csv"
# !bash "/content/gdrive/My Drive/Colab Notebooks/batch.sh"
# !head "/content/gdrive/My Drive/Colab Notebooks/datasets.csv"
# Out:
# done
# head: cannot open '/content/gdrive/My Drive/Colab Notebooks/datasets.csv' for reading: No such file or directory
