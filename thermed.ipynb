# %% [markdown]
# # Begining
# Starting with monting our drive for the datasets

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %% [markdown]
# # Training Model
# Loading the images dataset into memory and then training our model.

# %%
# !echo "[ ! ] Starting..."
# !cd "/content/gdrive/My Drive/Colab Notebooks" && python run.py # cd is a hack
# Out:
# [ ! ] Starting...
# Using TensorFlow backend.
# [ i ] There'is 11782 line in the data frame
# [ i ] loading images...
# [ * ] Loading 100% images
# tcmalloc: large alloc 1158217728 bytes == 0x5569a7b2e000 @  0x7f66068b51e7 0x7f660478d771 0x7f66047f228e 0x7f66047f2393 0x7f66048a895d 0x7f66048a92be 0x7f66048aa118 0x7f66049ed9be 0x7f66049ef5e4 0x7f66049f1eae 0x7f66049f2d5e 0x5569901fadd2 0x7f66048b22db 0x55699024bcae 0x55699024e1e2 0x55699020af1c 0x556990206d0a 0x556990206629 0x55699023761f 0x556990232322 0x55699023167d 0x5569901e01ab 0x7f66064b2b97 0x5569901dfa2a
# [ i ] processing data...
# WARNING: Logging before flag parsing goes to stderr.
# W0619 23:12:48.369405 140076177598336 deprecation_wrapper.py:119] From /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# ...
